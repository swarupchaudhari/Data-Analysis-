# %%
import json

# %%
#let write a fuction to load the data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("data.json")

# %%
data
# Out:
# {'name': 'Alive', 'company': 'IBM', 'salary': 45000}

# %%
type(data)
# Out:
# dict

# %% [raw]
# # Write a fuction to display user and their connec

# %%
def display_users(data):
    print("user and their conections:")
    for user in data['users']:
        print(f"ID:(user:-{user['name']} is friend with: {user['friends']} and liked page are {user['page']}")
    print("\npages information")
    for page in data["page"]:
        print(f"{page["id"]}:{page['name']}")
        
display_users(data)
# Out:
# user and their conections:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 9
#       6     for page in data["page"]:
#       7         print(f"{page["id"]}:{page['name']}")
# ----> 9 display_users(data)
#
# Cell In[12], line 3, in display_users(data)
#       1 def display_users(data):
#       2     print("user and their conections:")
# ----> 3     for user in data['users']:
#       4         print(f"{user['name']} is friend with: {user['friends']} and liked page are {user['page']}")
#       5     print("\npages information")
#
# KeyError: 'users'
