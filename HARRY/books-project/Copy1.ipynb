# %%
f = open("text.txt","r")

# %%
f.read()
# Out:
# '\nis\nthe\ngood\nboy\n'

# %%
s = "this is a right wat to lean data science"

# %%
f.close()

# %%
f = open("harry.txt","w")

# %%
f.write(s)
# Out:
# 40

# %%
f.close()

# %%
import json

# %%
obj = {"name": "Alive" , "company": "IBM" , "salary": 45000}
s = json.dumps(obj)
type(s)
print(s)
# Out:
# {"name": "Alive", "company": "IBM", "salary": 45000}

# %%
d = json.loads('{"name": "Alice", "company": "IBM", "salary": 45000}')

# %%
type(d)
# Out:
# dict

# %%
file = open("data.json","w")

# %%
json.dump(obj, file)

# %%
file.close()
