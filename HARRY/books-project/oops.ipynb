# %%
class Employee:
    company: "HP"
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
    def printDetails(self):
        print(f"The company of {self.name} is {self.company} with the salary ${self.salary}")

e = Employee("Harry", 47000)
e.printDetails
# Out:
# <bound method Employee.printDetails of <__main__.Employee object at 0x00000157BE5DCEC0>>

# %%
class Employee:
    company: "HP"
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
    def printDetails(self):
        print(f"The company of {self.name} is {self.company} with the salary ${self.salary}")

    @staticmethod
    def printTime():
        print(f"The time is now")

    @classmethod
    def printClassDetails(cls.company)")
        print(f"the company is {cls.company}")
        
        
e = Employee("Harry", 47000)
e.printDetails
e.printTime()
# Out:
# The time is now
