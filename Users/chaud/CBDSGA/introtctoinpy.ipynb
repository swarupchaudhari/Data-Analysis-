# %%
import sys
import time
size = 100
l1 = list(range(size))
l2 = list(range(size))

l3 = [x+y for x, y in zip(l1, l2)]
end_time = time.time()

print("python list took: ", end_took-start_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       7 l3 = [x+y for x, y in zip(l1, l2)]
#       8 end_time = time.time()
# ---> 10 print("python list took: ", end_took-start_time)
#
# NameError: name 'end_took' is not defined

# %%
n1 = np.arange(size)
n2 = np.arange(size)
n1[:4],n2[:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 n1 = np.arange(size)
#       2 n2 = np.arange(size)
#       3 n1[:4],n2[:4]
#
# NameError: name 'np' is not defined
