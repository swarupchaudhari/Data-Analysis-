# %%
f=open("funny.txt","r")

for line in f:
    print(line)

f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f=open("funny.txt","r")
#       3 for line in f:
#       4     print(line)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'funny.txt'

# %%
with open("funny.txt","r") as f:
    lines = f.readlines()
    for line in lines:
        print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open("funny.txt","r") as f:
#       2     lines = f.readlines()
#       3     for line in lines:
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'funny.txt'

# %%
with open("love.txt","w") as f:
    f.write("i love Python\n")
    f.write("i love Meditation")

# %%
with open("love.txt","w") as f:
    f.writelines([
        "i love java\n"
        "i love pandas"
    ])

# %%
with open("C:\\Users\\chaud\\CBDSGA\\score.csv", "r") as f:
    for line in f:
        player, match_id, score = line.split(",")
        print(player, match_id, score)
# Out:
# ï»¿rohit match#1 9
#
# mohit match#2 56
#
# bob match#3 56
#
# rohit match#4 120
#
# rohit match#5 105
#
# bob match#6 78
#
# rohit match#7 140
#
# bob match#8 45
#
# rohit match#9 130
#
# mohit match#10 102
#
# bob match#11 120
#
# bob match#12 5
#
# mohit match#13 72
#
# bob match#14 67

# %%
d = {
    'rohit': [9, 120, 105],
    'mohit': [5, 34, 20]
}
max(d['rohit'])
# Out:
# 120

# %%
player_scores = {}

with open("C:\\Users\\chaud\\CBDSGA\\score.csv", "r") as f:
    for line in f:
        player, _, score = line.split(",")
        score= int(score.strip())
        if player in player_scores:
            player_scores[player].append(score)
        else:
            player_score[player] = [score]
        player_scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 10
#       8     player_scores[player].append(score)
#       9 else:
# ---> 10     player_score[player] = [score]
#      11 player_scores
#
# NameError: name 'player_score' is not defined

# %%
player_scores = {}

with open("C:\\Users\\chaud\\CBDSGA\\score.csv", "r") as f:
    for line in f:
        player, _, score = line.split(",")   # FIXED: split()
        score = int(score.strip())

        if player in player_scores:
            player_scores[player].append(score)
        else:
            player_scores[player] = [score]  # FIXED: player_sc

player_scores
# Out:
# {'ï»¿rohit': [9],
#  'mohit': [56, 102, 72],
#  'bob': [56, 78, 45, 120, 5, 67],
#  'rohit': [120, 105, 140, 130]}

# %%
for player, score_list in player_scores.items():
    min_score=min(score_list)
    max_score=max(score_list)
    avg_score=sum(score_list)/len(score_list)
    print(f"{player} ==> Min:{min_score},Max:{max_score}, Avg:{avg_score}")
# Out:
# ï»¿rohit ==> Min:9,Max:9, Avg:9.0
# mohit ==> Min:56,Max:102, Avg:76.66666666666667
# bob ==> Min:5,Max:120, Avg:61.833333333333336
# rohit ==> Min:105,Max:140, Avg:123.75

# %%
with open("dummy.txt","w") as f:
    f.write("whatever")

# %%
import os
if os.path.exists('dummy.txt'):
    os.remove("dummy.txt")
else:
    print("file does not exist")
# Out:
# file does not exist

# %% [markdown]
# ##
