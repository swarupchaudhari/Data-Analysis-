# %%
import pandas as pd

# %%
df = pd.read_csv("movies.csv")
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.industry.unique()

# %%
df["language"].unique()

# %%
df.language,value_counts()

# %%
df_new = df[["title","imgb_rating","industry"]]
df_new
# Out:
#   Cell In[4], line 1
#     df_new = df[[title
#                       ^
# _IncompleteInputError: incomplete input

# %%
df[(df.release_year>=2000) & (df.release_year<=2010)]

# %%
df.studio.unique()

# %%
df.describe()

# %%
df[(df.imgb_rating==df.imgb_rating.max()) | (df.imgb_rating==df.imgb_rating.min())]

# %%
df.head(4)

# %%
df["age"] = df['release_year'].apply(lambda x: 2023 - x)
df.head(4)

# %%
df["profit"] = df.apply[lambda x: x['revanue'] - x['budget'], axis=1)
df.head(4)

# %%
df.index

# %%
df.set_index("title", inplace=True)

# %%
df.loc[["pather panchali", "Doctor strange"]]

# %%
df.iloc[0]

# %%
df.iloc[2:5]

# %%
df.reset_index(inplace= True)
df.head(4)
